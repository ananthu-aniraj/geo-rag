# %%
import ollama
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['/user/aaniraj/home/Documents/Projects/code/multimodal_RAG_elasticsearch/images_metadata/2507239560_After_the_Storm.jpg']
    }]
)

# %%
response.message.content
# Out:
# 'The image depicts a mountainous region, characterized by rolling hills and mountains in the background, with a valley in the middle. The landscape is covered with lush greenery, including trees and bushes, and features a cloudy sky.'

# %%
response = ollama.chat(
    model='qwen3-vl',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['/user/aaniraj/home/Documents/Projects/code/multimodal_RAG_elasticsearch/images_metadata/2507239560_After_the_Storm.jpg']
    }]
)
print(response.message.content)
# Out:
# This image depicts a **breathtaking landscape of a mountainous forested region** under an overcast sky. Key elements include:
#
# - **Rolling hills and mountains** covered in dense, lush forests. The trees display a mix of vibrant greens (suggesting healthy vegetation) and hints of autumnal reds/browns, indicating seasonal change.
# - **Valley formations** winding through the terrain, filled with thick woodland.
# - **Clouds and fog**—the sky is dominated by thick, gray clouds, with low-lying mist or fog clinging to the valleys and partially obscuring distant mountain peaks, creating a misty, atmospheric effect.
# - **Natural scenery** with no visible human structures, emphasizing the untouched, wild nature of the landscape.
#
# The overall mood is serene and tranquil, highlighting the beauty of a forested mountain range shrouded in cloud cover.

# %%
# %matplotlib inline
img_path = '/user/aaniraj/home/Documents/Projects/code/multimodal_RAG_elasticsearch/images_metadata/2507239560_After_the_Storm.jpg'
img = Image.open(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# %matplotlib inline
img_path_2 = "/user/aaniraj/home/Documents/Projects/data/LAION-final/291 lion, king of beasts, Panthera leo/counter-tree/htsrhrtjsrtjsrthrst.jpg"

img2 = Image.open(img_path_2)
plt.imshow(img2)
plt.axis('off')
plt.show()

# %%
response_3 = ollama.chat(
    model='qwen3-vl',
    messages=[{
        'role': 'user',
        'content': 'What is in this image? Is the salient object in the image an animal? If yes, which animal is it? Is this a common environment for this animal?',
        'images': [img_path_2]
    }]
)
print(response_3.message.content)
# Out:
# The image features a **lioness** (a female lion, identifiable by the absence of a prominent mane) walking on a tree branch in a natural landscape.
#
# ### Answers to your questions:
# 1. **What is in this image?**
#    A lioness on a tree branch, set against a backdrop of a grassy savanna with trees and a clear sky.
#
# 2. **Is the salient object in the image an animal? If yes, which animal is it?**
#    Yes, the salient object is an animal. It is a **lioness** (a female lion).
#
# 3. **Is this a common environment for this animal?**
#    Yes. Lions are native to **African savannas and grasslands** (and some parts of India), which match the open, grassy terrain with scattered trees and distant hills seen in the image. This environment is typical for lions, as it provides space for hunting, shelter, and social group dynamics.

# %%
response_4 = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image? Is the salient object in the image an animal? If yes, which animal is it? Is this a common environment for this animal?',
        'images': [img_path_2]
    }]
)
print(response_4.message.content)
